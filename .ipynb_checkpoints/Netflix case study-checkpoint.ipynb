# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import csv

# %%
df = pd.read_csv("C:\\Users\\jyks\\Downloads\\netflix_titles.csv")
print(df)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.ndim
#ndim represents the number of dimensions of the ndarray
#It is a 2-dimensional array
# Out:
# 2

# %%
df.shape
# shape explains the rowsxcolumns
# Out:
# (8807, 12)

# %%
df.head()
#head means the first 5 rows of the dataset will be displayed.
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.sample(5)
#Sample shows the randomly selected items in a sequence.
# Out:
#      show_id     type                          title        director  \
# 7905   s7906    Movie            Running Out Of Time    Chris Stokes
# 8482   s8483  TV Show                   The Returned             NaN
# 5465   s5466  TV Show                  The Dream Job             NaN
# 6708   s6709    Movie                       Euphoria  Valeria Golino
# 1860   s1861  TV Show  The Cabin with Bert Kreischer             NaN
#
#                                                    cast        country  \
# 7905  Tasha Smith, RonReaco Lee, Telma Hopkins, Sydn...  United States
# 8482  Anne Cosigny, Frédéric Pierrot, Clotilde Hesme...         France
# 5465  Hugo Ng, Shaun Chen, Jeanette Aw, Rebecca Lim,...      Singapore
# 6708  Riccardo Scamarcio, Valerio Mastandrea, Isabel...          Italy
# 1860  Bert Kreischer, Anthony Anderson, Caitlyn Jenn...  United States
#
#              date_added  release_year rating  duration  \
# 7905     August 1, 2019          2018  TV-14    88 min
# ...

# %%
df_cast_r = pd.DataFrame(df['cast'].apply(lambda x: str(x).split(',')).tolist(), index = df['title'])
#Using split function in a panda dataframe using apply
df_cast = df_cast_r.stack().reset_index()
#stack reshapes the dataframe into a table; converting the number of columns into rows; 
#level_1 is the index of cast for a specified title
df_cast.drop('level_1', axis = 1, inplace = True)
# drops the level_1 column, So axis should be 1; inplace is true means it will remove rows/columns in a original dataframe.
df_cast.rename(columns = {0: 'cast'}, inplace = True)
df_cast.head()
# Out:
#                   title             cast
# 0  Dick Johnson Is Dead              nan
# 1         Blood & Water       Ama Qamata
# 2         Blood & Water      Khosi Ngema
# 3         Blood & Water    Gail Mabalane
# 4         Blood & Water   Thabang Molaba

# %%
df_director_r = pd.DataFrame(df['director'].apply(lambda x: str(x).split(',')).tolist(), index = df['title'])
df_director = df_director_r.stack().reset_index()
df_director.drop('level_1', axis = 1, inplace = True)
df_director.rename(columns ={0: 'dierctor'}, inplace = True)
df_director.head()
# Out:
#                    title         dierctor
# 0   Dick Johnson Is Dead  Kirsten Johnson
# 1          Blood & Water              nan
# 2              Ganglands  Julien Leclercq
# 3  Jailbirds New Orleans              nan
# 4           Kota Factory              nan

# %%
df.count()
# Out:
# show_id         8807
# type            8807
# title           8807
# director        6173
# cast            7982
# country         7976
# date_added      8797
# release_year    8807
# rating          8803
# duration        8804
# listed_in       8807
# description     8807
# dtype: int64

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x="type", data=df, palette="Set1")

# %% [markdown]
# This chart shows that there were more movies than tv shows. # Comparison of movies vs tv shows
# Here Movie and TV show are categorical variables.
# Countplot in seaborn is used to count the observations in a categorical variable.

# %%
df_shows = df[df['type'] == 'TV Show']
df_movies = df[df['type'] == 'Movie']

# %%
#df_director_r = pd.DataFrame(df['director'].apply(lambda x: str(x).split(',')).tolist(), index = df['title'])
movies = pd.DataFrame(df[df.type == 'Movie'][['release_year']].value_counts(),columns=['counts'])
movies.sort_index(inplace=True)
movies.plot(kind='line',figsize=(20, 5))
plt.legend(['Count of Movies Released'])
plt.show()

# %%
df['date_added'] = pd.to_datetime(df['date_added'])
df['year_added'] = df.date_added.dt.year.astype('Int64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
#  12  year_added    8797 non-null   Int64
# dtypes: Int64(1), datetime64[ns](1), int64(1), object(10)
# memory usage: 903.2+ KB

# %%
df_range = df[df.year_added.isin(list(range(2013,2020)))][['year_added']]
df_range = pd.DataFrame(df_range.value_counts(),columns=['Count']).sort_index().reset_index()
df_range['per'] = df_range.Count.pct_change(fill_method ='ffill') * 100
df_range['per'] = df_range['per'].round(0)
df_range.dropna(inplace=True)
df_range
# Out:
#    year_added  Count    per
# 1        2014     24  118.0
# 2        2015     82  242.0
# 3        2016    429  423.0
# 4        2017   1188  177.0
# 5        2018   1649   39.0
# 6        2019   2016   22.0

# %%
plt.figure(figsize=(15,5))

bars = plt.bar(df_range['year_added'], height=df_range.Count,width=0.5,
               color=['#239c0e','#158701','#3f6e23','#30541a','#1b3b08','#203d0f'])

# %% [markdown]
# This shows that from 2014 to 2019 - Major shift is happened for netflix.
# Heatmap between 2014 and 2019 will help us to find how it reshaped across the months.

# %%
df_date = df_shows[['date_added']].dropna()
df_date['year']=df_date['date_added'].apply(lambda x: x.split( ', ')[-1])
df_date['month']=df_date['date_added'].apply(lambda x: x.lstrip().split( ' ')[0])

month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'][::-1]
df = df_date.groupby('year')['month'].value_counts().unstack().fillna(0)[month_order].T
plt.figure(figsize=(10, 7), dpi=200)
plt.pcolor(df, cmap='afmhot_r', edgecolors='white', linewidths=2) # heatmap
plt.xticks(np.arange(0.5, len(df.columns), 1), df.columns, fontsize=7, fontfamily='serif')
plt.yticks(np.arange(0.5, len(df.index), 1), df.index, fontsize=7, fontfamily='serif')

plt.title('Netflix Contents Update', fontsize=12, fontfamily='calibri', fontweight='bold', position=(0.20, 1.0+0.02))
cbar = plt.colorbar()

cbar.ax.tick_params(labelsize=8) 
cbar.ax.minorticks_on()
plt.show()

# %% [markdown]
# In 2021, January, March and May were the months that were comparatively much less content released.
# So, these months are a good choice for the success of new release.

# %%
df1 = pd.read_csv("C:\\Users\\jyks\\Downloads\\netflix_titles.csv")
df1.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df1[df1['duration'].isna()]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added  release_year  rating  \
# 5541  Louis C.K.  United States       April 4, 2017          2017  74 min
# 5794  Louis C.K.  United States  September 16, 2016          2010  84 min
# 5813  Louis C.K.  United States     August 15, 2016          2015  66 min
#
#      duration listed_in                                        description
# 5541      NaN    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794      NaN    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813      NaN    Movies  The comic puts his trademark hilarious/thought...

# %%
ind = df1[df1['duration'].isna()].index
df1.loc[ind] = df1.loc[ind].fillna(method = 'ffill' , axis = 1)
df1.loc[ind ,'rating'] = 'Not Available'
df1.loc[ind]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added release_year  \
# 5541  Louis C.K.  United States       April 4, 2017         2017
# 5794  Louis C.K.  United States  September 16, 2016         2010
# 5813  Louis C.K.  United States     August 15, 2016         2015
#
#              rating duration listed_in  \
# 5541  Not Available   74 min    Movies
# 5794  Not Available   84 min    Movies
# 5813  Not Available   66 min    Movies
#
#                                             description
# 5541  Louis C.K. muses on religion, eternal love, gi...
# 5794  Emmy-winning comedy writer Louis C.K. brings h...
# 5813  The comic puts his trademark hilarious/thought...

# %%
df1[df1.rating.isna()]
# Out:
#      show_id     type                                              title  \
# 5989   s5990    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 6827   s6828  TV Show                  Gargantia on the Verdurous Planet
# 7312   s7313  TV Show                                       Little Lunch
# 7537   s7538    Movie                               My Honor Was Loyalty
#
#              director                                               cast  \
# 5989              NaN                        Oprah Winfrey, Ava DuVernay
# 6827              NaN  Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, Ka...
# 7312              NaN  Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...
# 7537  Alessandro Pepe  Leone Frisa, Paolo Vaccarino, Francesco Miglio...
#
#         country        date_added release_year rating  duration  \
# 5989        NaN  January 26, 2017         2017    NaN    37 min
# 6827      Japan  December 1, 2016         2013    NaN  1 Season
# ...

# %%
indices = df1[df1.rating.isna()].index
indices
# Out:
# Int64Index([5989, 6827, 7312, 7537], dtype='int64')

# %%
df1.loc[indices , 'rating'] = 'Not Available'

# %%
df1.loc[indices]
# Out:
#      show_id     type                                              title  \
# 5989   s5990    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 6827   s6828  TV Show                  Gargantia on the Verdurous Planet
# 7312   s7313  TV Show                                       Little Lunch
# 7537   s7538    Movie                               My Honor Was Loyalty
#
#              director                                               cast  \
# 5989              NaN                        Oprah Winfrey, Ava DuVernay
# 6827              NaN  Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, Ka...
# 7312              NaN  Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...
# 7537  Alessandro Pepe  Leone Frisa, Paolo Vaccarino, Francesco Miglio...
#
#         country        date_added release_year         rating  duration  \
# 5989        NaN  January 26, 2017         2017  Not Available    37 min
# 6827      Japan  December 1, 2016         2013  Not Available  1 Season
# ...

# %%
df1.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', 'Not Available', 'NR', 'TV-Y7-FV', 'UR'],
#       dtype=object)

# %%
df1.rating.value_counts()
# Out:
# TV-MA            3207
# TV-14            2160
# TV-PG             863
# R                 799
# PG-13             490
# TV-Y7             334
# TV-Y              307
# PG                287
# TV-G              220
# NR                 80
# G                  41
# Not Available       7
# TV-Y7-FV            6
# NC-17               3
# UR                  3
# Name: rating, dtype: int64

# %% [markdown]
# Here we are removing the UR rating and adding it with NR (No ratings)

# %%
df1.loc[df1['rating'] == 'UR' , 'rating'] = 'NR'
df1.rating.value_counts()
# Out:
# TV-MA            3207
# TV-14            2160
# TV-PG             863
# R                 799
# PG-13             490
# TV-Y7             334
# TV-Y              307
# PG                287
# TV-G              220
# NR                 83
# G                  41
# Not Available       7
# TV-Y7-FV            6
# NC-17               3
# Name: rating, dtype: int64

# %%
df1_shows = df1[df1['type'] == 'TV Show']
df1_movies = df1[df1['type'] == 'Movie']
plt.figure(figsize=(12,10))
sns.set(style="darkgrid")
ax = sns.countplot(x="rating", data=df1_movies, palette="Set2", order=df1_movies['rating'].value_counts().index[0:15])

# %% [markdown]
# The above chart shows that major contribution of movies are with TV-MA rating : That means it is for mature audiences only.
# Second largest is for TV-14 (>14 years of age). while 3rd one is for R rating.

# %%
plt.figure(figsize=(12,10))
sns.set(style="darkgrid")
ax = sns.countplot(y="country", data=df1_movies, palette="Accent", order=df1_movies['country'].value_counts().index[0:15])

# %% [markdown]
# It is clearly evident that United states produced more movies, followed by India

# %%
plt.figure(figsize=(12,10))
sns.set(style="darkgrid")
ax = sns.countplot(y="country", data=df1_shows, palette="Accent", order=df1_shows['country'].value_counts().index[0:15])

# %% [markdown]
# In TV shows segment, US tops the chart followed by UK and Japan. India stands at 5th position.

# %%
print(df1_movies["listed_in"].value_counts()[:10])
plt.figure(figsize=(12,6))
sns.countplot(y='listed_in',data = df1_movies,order =df1_movies["listed_in"].value_counts().index[0:10],palette="Set1")
plt.title("Top 10 Genres of Movies",size=15)
plt.show()
# Out:
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Children & Family Movies                            215
# Children & Family Movies, Comedies                  201
# Documentaries, International Movies                 186
# Dramas, International Movies, Romantic Movies       180
# Comedies, International Movies                      176
# Name: listed_in, dtype: int64

# %% [markdown]
# The top 10 genres of movies listed mainly has Dramas with international movies following documentaries and Standup comedies.

# %%
df1_dramas=df1[df1["listed_in"] == "Dramas, International Movies"]
df1_dramas[["title","country","release_year"]].head(10)
# Out:
#                         title                                 country  \
# 12               Je Suis Karl                 Germany, Czech Republic
# 73               King of Boys                                 Nigeria
# 190                Thimmarusu                                   India
# 256  Nneka The Pretty Serpent                                     NaN
# 268                   Unroyal                                     NaN
# 285           The Railway Man  Switzerland, United Kingdom, Australia
# 306                       '76                                 Nigeria
# 315          Ije: The Journey                  United States, Nigeria
# 362             The Lost Café                                     NaN
# 498                     Clash                                     NaN
#
#     release_year
# 12          2021
# 73          2018
# 190         2021
# 256         2020
# 268         2020
# 285         2013
# 306         2016
# 315         2010
# 362         2018
# ...

# %% [markdown]
# Here, we can see the 10 dramas of the above genres.

# %% [markdown]
# # There are a mix of genres: To do that, we need to use dictionaries

# %%
from collections import Counter

# %%
df1_genres = list(df1_movies['listed_in'])
gen  = []
for i in df1_genres:
    i = list(i.split(','))
    for j in i:
        gen.append(j.replace(' ', ''))
g = Counter(gen)
g = sorted(g.items(), key = lambda item: g[item[0]], reverse = True)
df1_genre_names = [name for name , value in g]
df1_genre_values = [value for name ,value in g]

# %%
fig = plt.figure(figsize =(10,10))
ax = sns.barplot(x = df1_genre_names, y = df1_genre_values)

ax.set_xticklabels(df1_genre_names, rotation =70)
ax.set_ylabel('Count of movies')
ax.set_xlabel('Names of Genres')
plt.show()

# %% [markdown]
# In movies section, International movies are a major part in netflix followed by Dramas and Comedies

# %%
df1_oldest = df1.sort_values("release_year", ascending = True) 
df1_oldest[['title', "release_year"]][:5]
# Out:
#                                               title release_year
# 4250              Pioneers: First Women Filmmakers*         1925
# 7790                                 Prelude to War         1942
# 8205                           The Battle of Midway         1942
# 8660  Undercover: How to Operate Behind Enemy Lines         1943
# 8739             Why We Fight: The Battle of Russia         1943

# %% [markdown]
# Oldest movie recorded in 1925 named "Pioneers: First Women Filmmakers" were playing in Netflix

# %%
df1_movies['duration']
# Out:
# 0        90
# 6        91
# 7       125
# 9       104
# 12      127
#        ...
# 8801     96
# 8802    158
# 8804     88
# 8805     88
# 8806    111
# Name: duration, Length: 6131, dtype: int32

# %%
sns.set(style = 'darkgrid')
plt.figure(figsize = (10,8))
sns.kdeplot(data = df1_movies['duration'], shade = True);

# %% [markdown]
# This shows that the maximum duration of any movie lasts from 80-110 minutes.

# %%
# Maximum duration can be shown via scatter plot also.
fig = plt.figure(figsize=(12,8))
plt.scatter(df1_movies["release_year"], df1_movies["duration"])
plt.title("Duration of movies")
plt.show()

# %%
df1_movies['duration'].value_counts()
# Out:
# 90     152
# 94     146
# 97     146
# 93     146
# 91     144
#       ...
# 208      1
# 5        1
# 16       1
# 186      1
# 191      1
# Name: duration, Length: 205, dtype: int64

# %% [markdown]
# Maximum duration of movies in Netflix is 152 min long

# %%
df1_shows['duration'].value_counts()
# Out:
# 1 Season      1793
# 2 Seasons      425
# 3 Seasons      199
# 4 Seasons       95
# 5 Seasons       65
# 6 Seasons       33
# 7 Seasons       23
# 8 Seasons       17
# 9 Seasons        9
# 10 Seasons       7
# 13 Seasons       3
# 15 Seasons       2
# 12 Seasons       2
# 11 Seasons       2
# 17 Seasons       1
# Name: duration, dtype: int64

# %% [markdown]
# There are 1793 1 season; 425 2 seasons etc.

# %% [markdown]
# Insights based on Non-graphical and visual analysis:
# 1.	Netflix is a streaming platform where 70% comes from movies and 30% comes from TV-shows.
# 2.	The data contains different show id, type (Movies/TV shows), title of the type, director names, cast names, country names,  date added, release year, rating, duration, listed on and description etc.
# 3.	The following dataset is a 2-dimensional array. It has 8807 rows and 12 columns.
# 4.	Based on the count of movies released, in 2015, there is a major surge and fall of the trend occurs during the co-vid era.
# 5.	2018-19 witnessed a high in movies trend. Heatmap was drawn to indicate how the movies scaleup across the months.
# 6.	Some indices in rating and duration were having mismatch. It was corrected.
# 7.	Rating was high in TV-MA (Matured audiences); 2nd - TV-14 (>14 years of age); 3rd - R rated movies
# 8.	Country with the highest movies produced were United States, followed by India and UK.
# 9.	Country with the highest TV shows produced were United States, followed by UK and Japan.
# 10.	Genres is calculated based on "Listed in". Dramas and international movies tops the charts followed by Documentaries and Stand-up comedies.
# 11.	As multiple items were present in each genres, utilization of dictionaries helps to calculate the unique genres. With this, international movies tops the chart followed by Dramas and Comedies.
# 12.	Oldest movie played in Netflix is 1925 named "Pioneers: First Women Filmmakers"
# 13.	Maximum duration of any movie lasts between 80-110 mins. There were 90 movies with maximum duration of 152 mins.
# 14.	There were 1793 1 season tv shows followed by 425 2 seasons tv shows.
# Business Insights:
# 1. In Jan 2021, March and May were the months that were comparatively less content released. So, these months are a good choice for the success of new release i.e., the first H1 of the year should be focused more
# 2. Top 10 countries contribute the majority of portion in Netflix.
# 3. Shorter duration films can be increased gradually from 2019-2020. This can be increased further so that more reach can be possible.
# Recommendations:
# 1. Documentaries should be brought out more as all age groups will be focused.
# 2. Duration of the films is a key criterion as the audiences of TV-MA were more.
# 3. Only few countries have majority of movies; So, more business deals have to be created so that cultural diversity can be maintained.
# 4. More analysis to be drawn through a relationship between Genres with audiences and viewer’s time. This will help us to track the right audience.  So, a recommendation system to be created using statistical analysis to reduce the deviations (such as time consumed by audience on searching; frequently changing the videos by the audience).
# 5. A Likert scale has to be implemented in Netflix platform on a scale of (1-10) to get the feedback.
